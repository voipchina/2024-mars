# %%
import pandas as pd

import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv('/root/autodl-tmp/github/yolov10/runs/detect/train10/results.csv')
df.columns = df.columns.str.strip()
print(list(df.columns))
plt.plot(df['metrics/mAP50-95(B)'])
plt.xlabel('Index')
plt.ylabel('mAP50-95(B)')
plt.title('Line Plot of mAP50-95(B)')
plt.show()
# Out:
# ['epoch', 'train/box_om', 'train/cls_om', 'train/dfl_om', 'train/box_oo', 'train/cls_oo', 'train/dfl_oo', 'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)', 'val/box_om', 'val/cls_om', 'val/dfl_om', 'val/box_oo', 'val/cls_oo', 'val/dfl_oo', 'lr/pg0', 'lr/pg1', 'lr/pg2']

# %%
df[['train/box_om', 'train/cls_om', 'train/dfl_om', 'train/box_oo', 'train/cls_oo', 'train/dfl_oo']].plot()
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Line Plot')
plt.legend(loc='upper right')
plt.show()

# %%
df[['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']].plot()
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Line Plot')
plt.legend(loc='upper right')
plt.show()
